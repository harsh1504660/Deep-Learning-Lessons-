# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
sns.scatterplot(x=df['cgpa'],y=df['placement_exam_marks'],hue=df['placed'])
# Out:
# <AxesSubplot: xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
ndx = df.drop('placed',axis=1)
y = df['placed']

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-25.65,  -8.  ]])

# %%
p.intercept_
# Out:
# array([-15.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values , y.values , clf=p , legend=2)
# Out:
# E:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# E:\anaconda\lib\site-packages\mlxtend\plotting\decision_regions.py:315: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels, **contour_kwargs)
# <AxesSubplot: >

# %%
# note here percepton can not correctly classfy non linear data
